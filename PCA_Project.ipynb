# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("fedesoriano/heart-failure-prediction")
# Out:
# ...
# 100%|██████████| 8.56k/8.56k [00:00<00:00, 3.58MB/s]
# Extracting files...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print("Path to dataset files:", path)
# Out:
# Path to dataset files: /root/.cache/kagglehub/datasets/fedesoriano/heart-failure-prediction/versions/1

# %%
df = pd.read_csv("/content/heart.csv")

# %%
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %% [markdown]
# #Find z-score

# %%
df['Age'] = np.abs((df['Age'] - df['Age'].mean()) / df['Age'].std())
df['RestingBP'] = np.abs((df['RestingBP'] - df['RestingBP'].mean()) / df['RestingBP'].std())
df['Cholesterol'] = np.abs((df['Cholesterol'] - df['Cholesterol'].mean()) / df['Cholesterol'].std())
df['MaxHR'] = np.abs((df['MaxHR'] - df['MaxHR'].mean()) / df['MaxHR'].std())
df['Oldpeak'] = np.abs((df['Oldpeak'] - df['Oldpeak'].mean()) / df['Oldpeak'].std())
df['FastingBS'] = np.abs((df['FastingBS'] - df['FastingBS'].mean()) / df['FastingBS'].std())

# %%
df_no_outlier = df[(df['Age']<3) & df['Age']>-3]
df_no_outlier = df[(df['RestingBP']<3) & df['RestingBP']>-3]
df_no_outlier = df[(df['Cholesterol']<3) & df['Cholesterol']>-3]
df_no_outlier = df[(df['MaxHR']<3) & df['MaxHR']>-3]
df_no_outlier = df[(df['Oldpeak']<3) & df['Oldpeak']>-3]
df_no_outlier = df[(df['FastingBS']<3) & df['FastingBS']>-3]

# %%
df_no_age_outlier
# Out:
#           Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0    1.060129   M           ATA   0.410685     0.824621   0.551041     Normal
# 1    0.557719   F           NAP   1.490940     0.171867   0.551041     Normal
# 2    1.599411   M           ATA   0.129442     0.769768   0.551041         ST
# 3    0.377958   F           ASY   0.302660     0.138964   0.551041     Normal
# 4    1.280679   M           NAP   0.950812     0.034736   0.551041     Normal
# ..        ...  ..           ...        ...          ...        ...        ...
# 913  0.161325   M            TA   1.209697     0.596068   0.551041     Normal
# 914  1.235973   M           ASY   0.626736     0.053020   1.812770     Normal
# 915  0.741396   M           ASY   0.129442     0.619830   0.551041     Normal
# 916  0.741396   F           ATA   0.129442     0.340090   0.551041        LVH
# 917  1.419651   M           NAP   0.302660     0.217578   0.551041     Normal
#
# ...

# %% [markdown]
# #LabelEncoding

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df_no_outlier['Sex'] = label_encoder.fit_transform(df_no_outlier['Sex'])
df_no_outlier['ChestPainType'] = label_encoder.fit_transform(df_no_outlier['ChestPainType'])
df_no_outlier['RestingECG'] = label_encoder.fit_transform(df_no_outlier['RestingECG'])
df_no_outlier['ExerciseAngina'] = label_encoder.fit_transform(df_no_outlier['ExerciseAngina'])
df_no_outlier['ST_Slope'] = label_encoder.fit_transform(df_no_outlier['ST_Slope'])

# %%
df_no_outlier
# Out:
#           Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  \
# 0    1.060129    1              1   0.410685     0.824621   0.551041
# 1    0.557719    0              2   1.490940     0.171867   0.551041
# 2    1.599411    1              1   0.129442     0.769768   0.551041
# 3    0.377958    0              0   0.302660     0.138964   0.551041
# 4    1.280679    1              2   0.950812     0.034736   0.551041
# ..        ...  ...            ...        ...          ...        ...
# 913  0.161325    1              3   1.209697     0.596068   0.551041
# 914  1.235973    1              0   0.626736     0.053020   1.812770
# 915  0.741396    1              0   0.129442     0.619830   0.551041
# 916  0.741396    0              1   0.129442     0.340090   0.551041
# 917  1.419651    1              2   0.302660     0.217578   0.551041
#
#      RestingECG     MaxHR  ExerciseAngina   Oldpeak  ST_Slope  HeartDisease
# ...

# %%
Independent = df_no_outlier.iloc[0:,0:11].values
Dependent = df_no_outlier.iloc[0:,11:].values

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_scaled = scaler.fit_transform(Independent)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x_scaled,Dependent, test_size=0.2, random_state=10)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
model.score(x_test, y_test)
# Out:
# 0.842391304347826

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=0.9)

# %%
x_pca = pca.fit_transform(x_scaled)

# %%
x_pca.shape
# Out:
# (918, 10)

# %%
pca.explained_variance_ratio_
# Out:
# array([0.18472911, 0.11466543, 0.09869176, 0.09431533, 0.08938406,
#        0.08495191, 0.08129905, 0.07591477, 0.06916699, 0.06234242])

# %%
X_train_pca, X_test_pca, y_train, y_test = train_test_split(x_pca,Dependent,test_size = 0.2,random_state=30)

# %%
model = LogisticRegression()

# %%
model.fit(X_train_pca,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
model.score(X_test_pca,y_test)
# Out:
# 0.8532608695652174
